# %% [markdown]
# # 1. Traffic sign & light classification
# Traffic signs included in contest:
# - Stop
# - Parking
# - Crosswalk
# - Priority
# - Highway Entry
# - Highway End
# - One-way
# - Roundabout
# - No-entry
#
# (European standard)

# %% [markdown]
# ### SETUP

# %%
import os
import yaml
from ultralytics import YOLO

class YOLO11Trainer:
    def __init__(self, data_yaml, weight_src=None, model_size='n'):
        self.data_yaml = data_yaml
        if not os.path.exists(data_yaml):
            raise FileNotFoundError(f"Cannot file .yaml at {data_yaml}")
        if weight_src is not None:
            self.model = YOLO(weight_src)
        else:
            self.model = YOLO(f'yolo11{model_size}.pt')
        


    def update_data(self, data_yaml):
        self.data_yaml = data_yaml


    def train(self, yaml_params=None, **kwargs):
        if yaml_params is not None:
            with open(yaml_params, 'r') as f:
                train_params = yaml.safe_load(f)
        else:
            train_params = {}

        for key, val in list(kwargs.items()):
            train_params[key] = val

        metrics = self.model.train(data=self.data_yaml, **train_params)
        return metrics

# %% [markdown]
# ### INITIATING

# %%
trainer = YOLO11Trainer(
    data_yaml='dataset/MTSD.yaml',
    # model_size='s'
    weight_src='model/train_result/weights/best.pt'
)

# %%
# For 3.13 versions or lower
try:
    import albumentations as A

    custom_transforms = [
        # Blur variations
        A.OneOf(
            [
                A.MotionBlur(blur_limit=7, p=1.0),
                A.MedianBlur(blur_limit=7, p=1.0),
                A.GaussianBlur(blur_limit=7, p=1.0),
            ],
            p=0.3,
        ),


        # Noise variations
        A.OneOf(
            [
                A.GaussNoise(var_limit=(10.0, 50.0), p=1.0),
                A.ISONoise(color_shift=(0.01, 0.05), intensity=(0.1, 0.5), p=1.0),
            ],
            p=0.2,
        ),


        # Color and contrast adjustments
        A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), p=0.5),
        A.RandomBrightnessContrast(brightness_limit=0.3, contrast_limit=0.3, p=0.5),
        A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
        
        
        # Simulate occlusions
        A.CoarseDropout(
            max_holes=8, max_height=32, max_width=32, min_holes=1, min_height=8, min_width=8, fill_value=0, p=0.2
        ),
    ]
except ModuleNotFoundError:
    print('Albumentations only supports Python versions 3.9 - 3.13')
    custom_transforms = None or []
# Out:
# Albumentations only supports Python versions 3.9 - 3.13

# %% [markdown]
# ### TRAINING

# %%
metrics = trainer.train(
    # # Basic params
    # epochs=100,
    # patience=20,
    # batch=8,
    # imgsz=640,
    # save=True,


    # # Device management
    # device=-1,
    # workers=8,


    # # Optimizer
    # optimizer="AdamW",    
    # amp=True,
    # box=7.5,
    # cls=1.5,

    # # Learning planning
    # freeze=None,
    # classes=None,
    # cos_lr=False,
    # lr0=0.001,
    # lrf=0.1,


    # # Data aug.
    # multi_scale=True,
    # close_mosaic=10,
    # hsv_h=0.015,
    # hsv_s=0.7,
    # hsv_v=0.4,
    # degrees=10,
    # translate=0.1,
    # scale=0.25,
    # perspective=0.0005,
    # fliplr=0.5,
    # mosaic=1,
    # mixup=0.1,
    # cutmix=0.1,


    # # Misc
    # project=model,
    # name=train_result,
    # exist_ok=True,
    # profile=True,
    # plots=True,
    yaml_params='trainconfig.yaml',
    classes=list(range(17)),
    augmentations=custom_transforms
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.246 available  Update with 'pip install -U ultralytics'
# Searching for 1 idle GPUs with free memory >= 20.0% and free utilization >= 0.0%...
# WARNING No GPUs met criteria (free memory >= 20.0% and free utilization >= 0.0%).
# Ultralytics 8.3.241  Python-3.14.2 torch-2.9.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# ...

# %% [markdown]
# ### VALIDATING

# %%
from glob import glob
from PIL import Image
from IPython.display import display

for path in glob('model\\train_result\\*.jpg') + glob('model\\train_result\\*.png'):
    display(Image.open(path))

# %% [markdown]
# ### PREDICTING

# %%
imgs = glob('C:\\Users\\Bui Thien Nghia\\Documents\\PERSONAL FILES 2\\Cholibi-BFMC2026\\lab_n_archives\\traffic\\dataset\\Road_Sign_Detecting\\test\\1\\*.jpg')
for img in imgs[:10]:
    trainer.model.predict(img, imgsz=320, save=True)

# %%
len(imgs)

# %% [markdown]
# ### EXPORT MODEL

# %%
model = YOLO('runs/detect/train/weights/best.pt')

model.export(
    format='onnx',
    imgsz=416,
    dynamic=False,
    simplify=True
)
